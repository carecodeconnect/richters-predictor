# %%
import sys
sys.path.append('../src')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from load import load_train_data

pd.set_option('display.max_columns', None)

# %%
# Load data
train_data = load_train_data(local=True)
train_data.shape
# Out:
# (260601, 39)

# %%
# Filter dataset
cols_superstructure = [col for col in train_data.columns if 'superstructure' in col]
superstructure = train_data[cols_superstructure].copy()
superstructure.head()
# Out:
#              has_superstructure_adobe_mud  \
# building_id
# 802906                                  1
# 28830                                   0
# 94947                                   0
# 590882                                  0
# 201944                                  1
#
#              has_superstructure_mud_mortar_stone  \
# building_id
# 802906                                         1
# 28830                                          1
# 94947                                          1
# 590882                                         1
# 201944                                         0
#
#              has_superstructure_stone_flag  \
# building_id
# 802906                                   0
# 28830                                    0
# 94947                                    0
# 590882                                   0
# 201944                                   0
#
#              has_superstructure_cement_mortar_stone  \
# building_id
# 802906                                            0
# 28830                                             0
# 94947                                             0
# 590882                                            0
# 201944                                            0
#
#              has_superstructure_mud_mortar_brick  \
# building_id
# 802906                                         0
# 28830                                          0
# 94947                                          0
# 590882                                         0
# 201944                                         0
#
#              has_superstructure_cement_mortar_brick  \
# building_id
# 802906                                            0
# 28830                                             0
# 94947                                             0
# 590882                                            0
# 201944                                            0
#
#              has_superstructure_timber  has_superstructure_bamboo  \
# building_id
# 802906                               0                          0
# 28830                                0                          0
# 94947                                0                          0
# 590882                               1                          1
# 201944                               0                          0
#
#              has_superstructure_rc_non_engineered  \
# building_id
# 802906                                          0
# 28830                                           0
# 94947                                           0
# 590882                                          0
# 201944                                          0
#
#              has_superstructure_rc_engineered  has_superstructure_other
# building_id
# 802906                                      0                         0
# 28830                                       0                         0
# 94947                                       0                         0
# 590882                                      0                         0
# 201944                                      0                         0
